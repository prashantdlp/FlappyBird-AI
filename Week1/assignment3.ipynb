# %% [markdown]
# Importing the required libraries...

# %%
import pygame
import sys
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.1)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Setting the configurations for this "game"

# %%
WIDTH, HEIGHT = 400, 600
FPS = 60
GRAVITY = 0.6
FLAP_VELOCITY = -10
GROUND_HEIGHT = 100

# %% [markdown]
# Initializing the pygame

# %%
pygame.init()
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Flappy Bird — Mini Assignment")
clock = pygame.time.Clock()
font = pygame.font.SysFont(None, 32)

# %% [markdown]
# Setting initial state of the bird

# %%
bird_x = 80
bird_y = HEIGHT // 2
velocity = 0
bird_radius = 20

# %% [markdown]
# Function to draw background, ground and bird

# %%
def draw_screen():
  # sky blue color for the screen
  screen.fill((135, 206, 235))

  # ground
  pygame.draw.rect(screen, (94, 62, 14), (0, HEIGHT - GROUND_HEIGHT, WIDTH, GROUND_HEIGHT))

  # bird
  pygame.draw.circle(screen, (255, 220, 0), (int(bird_x), int(bird_y)), bird_radius)

  # text
  txt = font.render("press SPACE to flap", True, (0,0,0))
  screen.blit(txt, (10,10))

  pygame.display.flip()

# %% [markdown]
# Update bird physics
# ---
# Tasks :
# 1. if flap is true, set velocity to flap velocity
# 2. else apply gravity
# 3. update bird_y with velocity
# 4. prevent bird from falling below the ground

# %%
def update_bird(flap=False):

  global bird_y, velocity

  # TODO : Add your code here
  dt = 0.1 # THIS VALUE IS WORKING BETTER THAN 1/FPS DUE TO SMALL VELOCITY,GRAVITY,WINDOW VALUES

  if flap == True : 
    velocity = FLAP_VELOCITY  
  else :
    velocity += GRAVITY * dt
   
  bird_y += velocity * dt 
    
  if bird_y > HEIGHT - GROUND_HEIGHT :
    bird_y = HEIGHT - GROUND_HEIGHT - bird_radius 
    velocity = 0

# %%
def main():
    global velocity
    running = True

    while running:
        clock.tick(FPS)

        flap = False

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False

            # TODO: Detect SPACE key press and set flap = True
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_SPACE:
                    flap = True

        # TODO: Call update_bird with flap flag
        update_bird(flap)

        draw_screen()

    pygame.quit()
    sys.exit()

# %%
if __name__ == "__main__":
    main()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# c:\Users\Sures\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:3678: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
